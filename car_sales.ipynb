# %%
import requests

# %%
car_sales_url = "https://raw.githubusercontent.com/njoroge-alt/car_sales/refs/heads/main/car_sales.json"

# %%
car_sales_data = requests.get(car_sales_url)

# %%
car_sales_data
# Out:
# <Response [200]>

# %%
car_sales = car_sales_data.json()

# %%
type(car_sales)
# Out:
# list

# %%
import pandas

# %%
subset_data = car_sales[:100]

# %%
subset_df = pandas.DataFrame(subset_data)

# %%
subset_df.to_csv("carsalesdata.csv")
